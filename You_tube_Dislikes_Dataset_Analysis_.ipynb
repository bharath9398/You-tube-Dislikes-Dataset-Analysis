# %% [markdown]
# <a href="https://colab.research.google.com/github/bharath9398/You-tube-Dislikes-Dataset-Analysis/blob/Sattu_Bharath/You_tube_Dislikes_Dataset_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
k=pd.read_csv("/content/drive/MyDrive/project/youtube_dislike_dataset.csv")

# %%
k
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
#1) import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top5 and bottom 5 records.

k.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
#) import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top5 and bottom 5 records.

k.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
#2)  Check the info of the dataframe and write your inferences on data types and shape of the dataset.

k.info()
k.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB
# (37422, 12)

# %%
#2) observation ( Check the info of the dataframe and write your inferences on data types and shape of the dataset.)
#  *)The dataset consists of 37422 rows and it have non-values.
#  *)The data types vary among the columns. Several columns are of object type , while others are of int type.
#  *)The 'view_count', 'likes', 'dislikes', and 'comment_count' columns are stored as int.
#  *)The 'tags', 'title', 'channel_id', 'channel_title',' published_at', 'description', and 'comments' columns are stored as object type.

# %%
k.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
#3) Check for the Percentage of the missing values and drop or impute them

(k.isnull().sum()/t.shape[0])*100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
k.dropna(inplace=True)

# %%
k.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %%
#4. Check the statistical summary of both numerical and categorical columns and write your inferences.

k.describe(include="all")
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
# mean            NaN    NaN                       NaN                  NaN
# std             NaN    NaN                       NaN                  NaN
# min             NaN    NaN                       NaN                  NaN
# 25%             NaN    NaN                       NaN                  NaN
# 50%             NaN    NaN                       NaN                  NaN
# 75%             NaN    NaN                       NaN                  NaN
# max             NaN    NaN                       NaN                  NaN
#
#                published_at    view_count         likes      dislikes  \
# ...

# %%
#4) observation (Check the statistical summary of both numerical and categorical columns and write your inferences)
#  *) The statistical summary  calculates count,mean,std,min,max.........
#  *) The numerical columns consits of view_count,likes,dislikes.
#  *) Maximum views for a video is 1.322797e+09
#  *) Maximum Likes for a video is  3.183768e+07
#  *)Maximum Dislikes for a video is 2.397733e+06

# %%
#5.Convert datatype of column published_at from object to pandas datetime.

k["published_at"]=pd.to_datetime(k["published_at"])

# %%
k.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %%
#6.Create a new column as 'published_month' using the column published_at (display the months only)

import datetime as dt
k["published_month"]=t["published_at"].dt.month

# %%
k
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
k[['published_month']]
# Out:
#        published_month
# 0                    7
# 1                    6
# 2                    9
# 3                    3
# 4                   12
# ...                ...
# 37417                2
# 37418                1
# 37419                6
# 37420               10
# 37421                5
#
# [37264 rows x 1 columns]

# %%
#7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on.....

k['published_month']=k['published_at'].dt.month_name()

# %%
k
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
k[['published_month']]
# Out:
#       published_month
# 0                July
# 1                June
# 2           September
# 3               March
# 4            December
# ...               ...
# 37417        February
# 37418         January
# 37419            June
# 37420         October
# 37421             May
#
# [37264 rows x 1 columns]

# %%
#8) Find the number of videos published each month and arrange the months in a decreasing order basedon the video count

pd.DataFrame(k.groupby('published_month')['video_id'].count().sort_values(ascending=False))
# Out:
#                  video_id
# published_month
# October              4976
# September            4854
# November             4821
# August               4250
# December             3063
# July                 2331
# June                 2305
# March                2248
# February             2125
# April                2119
# January              2099
# May                  2073

# %%
#9 Find the count of unique video_id, channel_id and channel_title.

k[['video_id','channel_id','channel_title']].nunique()
# Out:
# video_id         37264
# channel_id       10891
# channel_title    10813
# dtype: int64

# %%
#10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

pd.DataFrame(k.groupby('channel_title')['video_id'].count().sort_values(ascending=False).head(10))
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
pd.DataFrame(k.groupby('channel_title')['video_id'].count().sort_values(ascending=False).tail(10))
# Out:
#                  video_id
# channel_title
# Karikku Tuned           1
# Karen Bustillos         1
# Karen Aslanyan          1
# Karchez                 1
# Karate Combat           1
# Kaptain Kuba            1
# Kanye West              1
# Kannur kitchen          1
# Kannada Cinema          1
# zoom                    1

# %%
# 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

k[['title','likes']].groupby('title').max().sort_values(by="likes",ascending=False).head(1)
# Out:
#                                   likes
# title
# BTS () 'Dynamite' Official MV  31837675

# %%
k[['title','likes']].groupby('title').min().sort_values(by="likes",ascending=False).tail(1)
# Out:
#                                likes
# title
# Leading the Charge | Circle K     22

# %%
# 11. observation (Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences)
# *) The title of the video with maximum number  of likes is BTS () 'Dynamite' Official MV	31837675 likes.
# *)  The title of the video with minimum number of likes is Leading the Charge | Circle K	22 likes.

# %%
#12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inference

a=k[["title","dislikes"]].groupby("title").max().sort_values(by="dislikes",ascending=False).head(1)
a
# Out:
#                                      dislikes
# title
# Cuties | Official Trailer | Netflix   2397733

# %%
b=k[["title","dislikes"]].groupby("title").min().sort_values(by="dislikes",ascending=False).tail(1)
b
# Out:
#                                         dislikes
# title
# Tims For Good: A Taste Of The Familiar         3

# %%
#12 .observations (Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.)
#   *)The title of the video with maximum number  of dislikes is Cuties & Official Trailer &  Netflix	2397733 likes.
#   *)The title of the video with minimum number of dislikes is Tims For Good: A Taste Of The Familiar	3 likes.

# %%
#13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lineplot(x="view_count",y="dislikes",data=k)
# Out:
# <Axes: xlabel='view_count', ylabel='dislikes'>

# %%
pd.DataFrame(k[['dislikes','view_count']]).plot(x='view_count',y='dislikes',kind='scatter')
# Out:
# <Axes: xlabel='view_count', ylabel='dislikes'>

# %%
sns.heatmap(k.corr(),annot=True)
# Out:
# <ipython-input-151-6d9a59fbf86d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(k.corr(),annot=True)
# <Axes: >

# %%
# 13) observation(Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.)
# *) The correlation between views and dislikes is 0.684. It means it's having a direct relation and increase in one leads to increase in another and vice-versa

# %%
 #14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

k[k["published_month"]=="January"]["video_id"].count()
# Out:
# 2099
